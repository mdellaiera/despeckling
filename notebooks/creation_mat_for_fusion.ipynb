# %% [markdown]
# # Test

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
folder = '/home/nus/workspace/despeckling/dataset/fusion/'

opt = np.array(Image.open(folder + 'opt.png')).astype(np.float32)
sar = np.array(Image.open(folder + 'sar.png')).astype(np.float32) 

print(opt.shape, sar.shape)
# Out:
# (708, 1007, 4) (708, 1007)

# %%
# create the .mat file
import scipy.io as sio
sio.savemat(folder + 'opt.mat', {'data': opt})
sio.savemat(folder + 'sar.mat', {'data': sar})
