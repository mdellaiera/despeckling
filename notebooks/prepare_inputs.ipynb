# %% [markdown]
# # Prepare inputs

# %%
import scipy.io
import numpy as np

# %%
path_input = '../../dataset/clip_T1.mat'

data = scipy.io.loadmat(path_input)
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'L', 'enl_area', 'guide', 'noisy'])

# %%
eo = data['guide']
sar = data['noisy']

eo.min(), eo.max(), sar.min(), sar.max()
# Out:
# (np.uint8(0), np.uint8(255), np.float64(0.0), np.float64(13214.244140625))

# %%
np.savez_compressed('../../dataset/data.npz', **{'eo': eo, 'sar': sar})
